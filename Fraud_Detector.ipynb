# %%
import numpy as np
import pandas as pd                   #Feature Selection For ML Model From Given Dataset
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mode
from sklearn.model_selection import train_test_split

df=pd.read_csv("fraudTrain.csv")
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
# 5           5   2019-01-01 00:04:08  4767265376804500
# 6           6   2019-01-01 00:04:42    30074693890476
# 7           7   2019-01-01 00:05:08  6011360759745864
# 8           8   2019-01-01 00:05:18  4922710831011201
# 9           9   2019-01-01 00:06:01  2720830304681674
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# ...

# %%
sns.pairplot(data=df,hue="is_fraud")           #Graphical Representation Of Dataset
plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-75d23b3c0561>", line 1, in <cell line: 0>
#     sns.pairplot(data=df,hue="is_fraud")           #Graphical Representation Of Dataset
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py", line 2177, in pairplot
#     grid.add_legend()
#   File "/usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py", line 195, in add_legend
#     _draw_figure(self._figure)
#   File "/usr/local/lib/python3.11/dist-packages/seaborn/utils.py", line 61, in _draw_figure
#     fig.canvas.draw()
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py", line 382, in draw
# ...

# %%
from sklearn.preprocessing import LabelEncoder      #Use Label Encoding to convert categorical data into numeric
la = LabelEncoder()
label_encoder_arr={}
for i in df.select_dtypes(include=['object']).columns:
 la = LabelEncoder()
 df[i]=la.fit_transform(df[i])
 label_encoder_arr[i] = la

# %%
df.drop(columns="Unnamed: 0",inplace= True)

# %%
for col in df.select_dtypes(include='number').columns:      #Filling Null Values In Whole Dataset
    df[col] = df[col].fillna(df[col].mean())

# %%
df1=pd.read_csv("fraudTest.csv")

la1 = LabelEncoder()
label_encoder_arr={}
for i in df1.select_dtypes(include=['object']).columns:
 la1 = LabelEncoder()
 df1[i]=la1.fit_transform(df1[i])
 label_encoder_arr[i] = la1

# %%
from sklearn.preprocessing import StandardScaler

df1.drop(columns="Unnamed: 0",inplace= True)
X = df.drop('is_fraud', axis=1)  # Ensure the target column is dropped
y = df['is_fraud'].astype(int).values

X1 = df1.drop('is_fraud', axis=1)  # Ensure the target column is dropped
y1 = df1['is_fraud'].astype(int).values
#Scaling Data to put Dataset in Normal Distribution
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X1)

# %%
df.head(3)
# Out:
#    trans_date_trans_time            cc_num  merchant  category     amt  first  \
# 0                      0  2703186189652095       514         8    4.97    152
# 1                      1      630423337322       241         4  107.23    296
# 2                      2    38859492057661       390         0  220.11    105
#
#    last  gender  street  city  ...      lat      long  city_pop  job  dob  \
# 0    18       0     532   498  ...  36.0788  -81.1781    3495.0  359  726
# 1   155       0     410   573  ...  48.8878 -118.2105     149.0  414  554
# 2   374       1     565   444  ...  42.1808 -112.2620    4154.0  297  266
#
#    trans_num     unix_time  merch_lat  merch_long  is_fraud
# 0       3215  1.325376e+09  36.011293  -82.048315       0.0
# 1       9026  1.325376e+09  49.159047 -118.186462       0.0
# 2      46626  1.325376e+09  43.150704 -112.154481       0.0
#
# [3 rows x 22 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
m = LogisticRegression(max_iter=200)         #Training Logistic Regression Model
fs = SequentialFeatureSelector(m, n_features_to_select=8, direction="forward")   #Feature Selecting
fs.fit(X, y)


# Extracting selected features from dataset
selected_features = fs.get_support(indices=True)
X_train_selected = X_train_scaled[:, selected_features]
X_test_selected = X_test_scaled[:, selected_features]
XX = X_test_scaled[:, selected_features]

# Training model on selected features
m.fit(X_train_selected, y)
# Out:
# LogisticRegression(max_iter=200)

# %%
from sklearn.metrics import accuracy_score

# Predict and evaluate
y_pred = m.predict(X_test_selected)
print(y_test.shape,y_pred.shape)
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", accuracy*100,"%")
# Out:
# (555719,) (555719,)
# Model Accuracy: 99.43082745056404 %

# %%
# Add the predictions to a separate dataframe that corresponds to the test set (X_test)
predictions_df = pd.DataFrame(y_pred, columns=["Prediction"])
predictions_df
# Out:
#         Prediction
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 555714           0
# 555715           0
# 555716           0
# 555717           0
# 555718           0
#
# [555719 rows x 1 columns]

# %%
# Prediction Analysis using classification report
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions_df))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.07      0.04      0.05      2145
#
#     accuracy                           0.99    555719
#    macro avg       0.53      0.52      0.52    555719
# weighted avg       0.99      0.99      0.99    555719

# %%
import numpy as np
import pandas as pd

# Example: Provide a dictionary with your input values
manual_input = {
    'trans_date_trans_time': 0,
    'cc_num': 2703186189652095,
    'merchant': 514,
    'category': 300,
    'amt': 8	,
    'first': 4.97	,
    'last': 152	,
    'gender': 18,
    'street': 0,
    'city': 532,
    'state': 498,
    'zip': 1,
    'lat': 36.0788,
    'long':	-81.1781,
    'city_pop':	3495.0 ,
    'job': 	359	 ,
    'dob': 726	,
    'trans_num':3215	,
    'unix_time': 1.325376e+09	 ,
    'merch_lat': 36.011293	,
    'merch_long': -82.048315,
                                                           # Total 21 features
}
manual_input_df = pd.DataFrame([manual_input])             # Converting Dictionary input into dataframe

manual_input_scaled = scaler.transform(manual_input_df)    # Scaling input

manual_input_selected = manual_input_scaled[:, selected_features]


prediction = m.predict(manual_input_selected)[0]           # Predicting
if(prediction==0):
 print("Transaction is Legitimate")
else:                                                      # Printing Prediction
 print("Transaction is Fradulent")
# Out:
# Transaction is Legitimate
